# %%
import pandas as pd
import set_paths
from config.paths import SCHEMAS, DATA, CRM, CITAS, INTERESADOS, ESTAD_PORTALES
from src.clean_tables import load_table
from src.utils import get_files

# %%
table_path = get_files(CRM)[0]
test = load_table(path = CRM/table_path,
           yaml_path = SCHEMAS/"leads_table.YAML")
test
# Out:
#       id_lead          nombre  apellido                          email  \
# 0        5735  Gladys Estrada     Alejo  gladysestrada1085@hotmail.com
# 1        5734        naymarin         N           naymarin81@gmail.com
# 2        5733        naymarin         N           naymarin81@gmail.com
# 3        5732           Elvia         N           elvia.ab76@gmail.com
# 4        5731          Monica         N            moan31@yahoo.com.mx
# ...       ...             ...       ...                            ...
# 4847     9759          Isabel         N     Cyberpalomitas@outlook.com
# 4848     9758          Isabel         N     Cyberpalomitas@outlook.com
# 4849     9756          Daniel   Cuautle                           <NA>
# 4850     9755          Mayela      <NA>      zarazua.mayela9@gmail.com
# 4851     9754        Granados  Granados     aguilar.bienes33@gmail.com
#
#           telefono portal_origen          tipo operacion   precio  \
# 0     525547079333   Inmuebles24  departamento   comprar  1236498
# 1     525617758225   Inmuebles24  departamento   comprar   986263
# 2     525617758225   Inmuebles24          casa   comprar   850000
# 3     525566031276   Inmuebles24  departamento   comprar   970000
# 4     525534767305   Inmuebles24  departamento   comprar  1738188
# ...            ...           ...           ...       ...      ...
# 4847    7471949713   Inmuebles24  departamento   comprar  1140000
# 4848    7471949713   Inmuebles24  departamento   comprar  1140000
# 4849    5574261711       Cartera        duplex   comprar   510000
# 4850    5534285712   Inmuebles24  departamento   comprar  1569100
# 4851    5641235367   Inmuebles24  departamento   comprar  2165000
#
#                 estado  ... fecha_ultima_actividad  \
# 0     Ciudad de México  ...                    NaT
# 1     Ciudad de México  ...                    NaT
# 2     Estado de México  ...                    NaT
# 3     Estado de México  ...                    NaT
# 4     Ciudad de México  ...    2026-06-19 11:03:00
# ...                ...  ...                    ...
# 4847  Ciudad de México  ...                    NaT
# 4848  Ciudad de México  ...                    NaT
# 4849             edomx  ...                    NaT
# 4850             edomx  ...                    NaT
# 4851              CDMX  ...                    NaT
#
#                  ultimo_asesor_activo abierto hubo_venta_pago solo_firmado  \
# 0                                <NA>    True           False        False
# 1                                <NA>    True           False        False
# 2                                <NA>    True           False        False
# 3                                <NA>    True           False        False
# 4        Luis Néstor Portilla Vázquez    True           False        False
# ...                               ...     ...             ...          ...
# 4847    Victor Manuel Garcia Bautista   False           False        False
# 4848    Victor Manuel Garcia Bautista   False           False        False
# 4849  Diana Elizabeth Vivanco Galindo    True           False        False
# 4850  Diana Elizabeth Vivanco Galindo   False           False        False
# 4851  Diana Elizabeth Vivanco Galindo   False           False        False
#
#      monto_venta fecha_cierre  fecha_cierre_venta dias_activo   id_aviso
# 0              0          NaT                 NaT           0          0
# 1              0          NaT                 NaT           0          0
# 2              0          NaT                 NaT           0          0
# 3              0          NaT                 NaT           0          0
# 4              0          NaT                 NaT           0          0
# ...          ...          ...                 ...         ...        ...
# 4847           0          NaT                 NaT           6  147135173
# 4848           0          NaT                 NaT           6          0
# 4849           0          NaT                 NaT          10          0
# 4850           0          NaT                 NaT           0  150794290
# 4851           0          NaT                 NaT           0  150778390
#
# [4852 rows x 43 columns]

# %%
citas_test_path = get_files(CITAS)[0]
citas_test = load_table(path=CITAS / citas_test_path,
                        yaml_path= SCHEMAS/"citas_table.YAML")
citas_test
# Out:
#     id_cita fecha_solicitud fecha_cita          cliente             asesor  \
# 0      5281      2026-08-19 2026-08-21        Ricardo N  Valentina Salgado
# 1      9109      2026-08-18 2026-08-21  Adrian Ambrocio      Daniel Guerra
# 2      9110      2026-08-18 2026-08-21      Jesus Gomez      Daniel Guerra
# 3      9304      2026-08-21 2026-08-22     Johana Moran   Patricia Mijares
# 4      5281      2026-08-20 2026-08-22        Ricardo N  Valentina Salgado
# 5      8919      2023-08-19 2026-08-23     Erick Iñaqui  Valentina Salgado
# 6      9267      2026-08-20 2026-08-23      Angel Perez      Yolanda Rojas
# 7      8919      2026-08-19 2026-08-23     Erick Iñaqui  Valentina Salgado
# 8      5281      2026-08-20 2026-08-24        Ricardo N  Valentina Salgado
# 9      9376      2026-08-23 2026-08-24            Tania      Daniel Guerra
# 10     8844      2026-08-18 2026-08-24          Angel N   Patricia Mijares
# 11     9478      2026-08-24 2026-08-24           Xareni       Omar  Moreno
# 12     9249      2026-08-24 2026-08-24  Laura santander      Diana Vivanco
# 13     9249      2026-08-20 2026-08-24  Laura santander      Diana Vivanco
# 14     9028      2026-08-25 2026-08-25    Xareni Corona  Valentina Salgado
# 15     9478      2026-08-24 2026-08-25           Xareni       Omar  Moreno
# 16     8844      2026-08-24 2026-08-25          Angel N   Patricia Mijares
# 17     9109      2026-08-18 2026-08-25  Adrian Ambrocio      Daniel Guerra
# 18     9028      2026-08-25 2026-08-25    Xareni Corona  Valentina Salgado
# 19     9377      2026-08-24 2026-08-26           Nayely      Diana Vivanco
# 20     9450      2026-08-27 2026-08-27      Christian N      Daniel Guerra
#
#              gerente  asistencia  n_cita     producto   tipo_cita  \
# 0   Leonardo Furlong  reagendada       5       outlet  Presencial
# 1   Leonardo Furlong    atendida       1  Residencial    Inmueble
# 2   Leonardo Furlong   cancelada       2  Residencial    Inmueble
# 3      Victor Garcia   cancelada       1       outlet  Presencial
# 4   Leonardo Furlong  reagendada       6       outlet  Presencial
# 5   Leonardo Furlong  reagendada       1  Residencial    Inmueble
# 6   Leonardo Furlong   cancelada       1  Residencial    Inmueble
# 7   Leonardo Furlong   cancelada       2  Residencial    Inmueble
# 8   Leonardo Furlong    atendida       7       outlet  Presencial
# 9   Leonardo Furlong    atendida       1  Residencial    Inmueble
# 10     Victor Garcia  reagendada       1       outlet  Presencial
# 11     Jaime Morales    atendida       2        Micro  Presencial
# 12       Omar Moreno   cancelada       1       outlet  Presencial
# 13       Omar Moreno  reagendada       2       outlet  Presencial
# 14  Leonardo Furlong  reagendada       1  Residencial  Presencial
# 15     Jaime Morales    atendida       3        Micro  Presencial
# 16     Victor Garcia   cancelada       2       outlet  Presencial
# 17  Leonardo Furlong  reagendada       2  Residencial    Inmueble
# 18  Leonardo Furlong    atendida       2  Residencial  Presencial
# 19       Omar Moreno  reagendada       1       outlet  Presencial
# 20  Leonardo Furlong    atendida       1  Residencial    Inmueble
#
#          captacion  registrado_crm  ventas
# 0     Inmuebles 24            True       0
# 1   Redes Sociales            True       0
# 2   Redes Sociales            True       0
# 3        Marketing            True       0
# 4     Inmuebles 24            True       0
# 5   Redes Sociales            True       0
# 6   Redes Sociales            True       0
# 7   Redes Sociales            True       0
# 8     Inmuebles 24            True       1
# 9   Redes Sociales            True       0
# 10    Inmuebles 24            True       0
# 11    Inmuebles 24            True       0
# 12    Inmuebles 24            True       0
# 13    Inmuebles 24            True       0
# 14  Redes Sociales            True       0
# 15    Inmuebles 24            True       0
# 16    Inmuebles 24            True       0
# 17  Redes Sociales            True       0
# 18  Redes Sociales            True       0
# 19    Inmuebles 24            True       0
# 20    Inmuebles 24            True       0

# %%
inter_test_path = get_files(INTERESADOS)[0]
inter_test = load_table(path=INTERESADOS / inter_test_path,
                        yaml_path= SCHEMAS/"interesados_table.YAML")
inter_test
# Out:
#                            nombre_apellido                           email  \
# 0                    Omar Cardenas Escobar   omarcardenasescobar@gmail.com
# 1                              Erika Ceron         ceronerika097@gmail.com
# 2               AILED ADRIANA PLATA GARCIA  adriana.plata.garcia@gmail.com
# 3    Rafaela del Rosario Basílio Gutiérrez           basiliogtrz@gmail.com
# 4                              Betsua Ruiz           betadonay@hotmail.com
# ..                                     ...                             ...
# 136                                  Jesus            j.jc2001@hotmail.com
# 137                                  Roger          roger.castillo@sweq.mx
# 138                   Jorge Calcaneo Vidal    calcaneovidaljorge@gmail.com
# 139                          Daniela Parra     daniparra.oficial@gmail.com
# 140                               veronica        verodiaz27diaz@gmail.com
#
#          telefono    telefono_2                         sucursal  \
# 0    525522632696  525522632696  ALTALTIUM REAL ESTATES VENTAS 1
# 1    525559198072  525540162147  ALTALTIUM REAL ESTATES VENTAS 1
# 2      7222522654    7222522654  ALTALTIUM REAL ESTATES VENTAS 1
# 3      7441572580    7441572580  ALTALTIUM REAL ESTATES VENTAS 1
# 4      5548462589  525548462589  ALTALTIUM REAL ESTATES VENTAS 1
# ..            ...           ...                              ...
# 136  525548828047          <NA>  ALTALTIUM REAL ESTATES VENTAS 1
# 137  525537331753  525537331753  ALTALTIUM REAL ESTATES VENTAS 1
# 138  529994484743  529994484743  ALTALTIUM REAL ESTATES VENTAS 1
# 139    5633433616          <NA>  ALTALTIUM REAL ESTATES VENTAS 1
# 140  525518848018  525518848018  ALTALTIUM REAL ESTATES VENTAS 1
#
#                                                mensaje               fecha  \
# 0                                Contactó por Whatsapp 2026-08-27 22:32:00
# 1                         Pregunta: ¿Sigue disponible? 2026-08-27 22:18:00
# 2                                         Vió teléfono 2026-08-27 22:10:00
# 3    Pregunta: En qué etapa está? Se paga directo a... 2026-08-27 22:07:00
# 4                                         Vió teléfono 2026-08-27 19:53:00
# ..                                                 ...                 ...
# 136                              Contactó por Whatsapp 2026-08-21 11:26:00
# 137                                       Vió teléfono 2026-08-21 11:05:00
# 138  ¡Hola! Quiero recibir información de sus inmue... 2026-08-21 03:30:00
# 139                              Contactó por Whatsapp 2026-08-21 02:35:00
# 140  ¡Hola! Quiero que se comuniquen conmigo por es... 2026-08-21 02:10:00
#
#       id_aviso   codigo         provincia                 ciudad  \
# 0    150834569     Ar68  Ciudad de México               Coyoacán
# 1    148412855     NA03  Ciudad de México             Xochimilco
# 2    150883227  AR68 01  Ciudad de México  Cuajimalpa de Morelos
# 3    150770620     CA72  Ciudad de México               Coyoacán
# 4    150778338     DV52  Ciudad de México          Benito Juárez
# ..         ...      ...               ...                    ...
# 136  150778622     JN79    Edo. de México   Atizapán de Zaragoza
# 137  150794290     DV52    Edo. de México   Atizapán de Zaragoza
# 138          0     <NA>              <NA>                   <NA>
# 139  150807995     AF78  Ciudad de México         Miguel Hidalgo
# 140  150792676     DV52  Ciudad de México    Venustiano Carranza
#
#                           barrio tipo_propiedad tipo_operacion   precio  \
# 0            Copilco Universidad   Departamento          Venta  1575204
# 1    Ampliación San Marcos Norte   Departamento          Venta  1120000
# 2                      Contadero   Departamento          Venta  2150204
# 3             Paseos de Taxqueña           Casa          Venta  1100000
# 4                        Nápoles   Departamento          Venta  1810000
# ..                           ...            ...            ...      ...
# 136         Condado de Sayavedra           Casa          Venta  1400000
# 137         Rincón de la Montaña   Departamento          Venta  1569100
# 138                         <NA>           <NA>           <NA>     <NA>
# 139          Bosque de las Lomas           Casa          Venta  5550000
# 140              Jardín Balbuena   Departamento          Venta  1960200
#
#                                                 titulo  \
# 0    VENTA DE DEPARTAMENTO EN AVENIDA UNIVERSIDAD C...
# 1    *DEPARTAMENTO EN VENTA* en Ahuejotes, Colonia ...
# 2    DEPARTAMENTO EN VENTA EN CONTADERO EN STAMPA R...
# 3    Casa en Remate en Zona Exclusiva y Tranquila e...
# 4    Departamento en venta en Arkansas, colonia Náp...
# ..                                                 ...
# 136  CASA EXCLUSIVA EN VENTA EN CONDADO DE SAYAVEDR...
# 137      Departamento en venta en Rincón de la Montaña
# 138                                               <NA>
# 139  CASA BOSQUE DE LOS CIRUELOS, FRACC BOSQUE DE L...
# 140              Departamento en venta Jardín Balbuena
#
#                                              url_aviso
# 0    https://www.inmuebles24.com/propiedades/-15083...
# 1    https://www.inmuebles24.com/propiedades/-14841...
# 2    https://www.inmuebles24.com/propiedades/-15088...
# 3    https://www.inmuebles24.com/propiedades/-15077...
# 4    https://www.inmuebles24.com/propiedades/-15077...
# ..                                                 ...
# 136  https://www.inmuebles24.com/propiedades/-15077...
# 137  https://www.inmuebles24.com/propiedades/-15079...
# 138                                               <NA>
# 139  https://www.inmuebles24.com/propiedades/-15080...
# 140  https://www.inmuebles24.com/propiedades/-15079...
#
# [141 rows x 17 columns]

# %%
import pandas as pd
import yaml
import psycopg2
from psycopg2.extras import execute_values


def insert_table(
    df: pd.DataFrame,
    yaml_path: str,
    connection
):
    with open(yaml_path, "r", encoding="utf-8") as file:
        config = yaml.safe_load(file)

    table_name = config["table"]

    columns = [
        column
        for column in config["columns"]
        if column["keep"]
    ]

    column_names = [column["name"] for column in columns]

    # Crear tabla si no existe
    definitions = ", ".join(
        f'"{column["name"]}" {column["sql_type"]}'
        for column in columns
    )

    create_query = f"""
        CREATE TABLE IF NOT EXISTS "{table_name}" (
            {definitions}
        );
    """

    cursor = connection.cursor()
    cursor.execute(create_query)

    # Preparar INSERT
    names = ", ".join(
        f'"{name}"'
        for name in column_names
    )

    insert_query = f"""
        INSERT INTO "{table_name}" ({names})
        VALUES %s;
    """

    # Convertir valores faltantes de pandas a None
    data = (
        df[column_names]
        .astype(object)
        .where(pd.notna(df[column_names]), None)
        .itertuples(index=False, name=None)
    )

    execute_values(
        cursor,
        insert_query,
        data
    )

    connection.commit()
    cursor.close()

# %%
from src.db.connect import get_connection
conn = get_connection()
insert_table(
    test,
    "schemas/leads.yaml",
    connection
)

connection.close()
